# %% [markdown]
# # Advent of Code 2023

# %%
from collections import defaultdict
file = open('day_1_1.txt').read().strip().split('\n')
display(file[0])
# Out:
# 'Card   1:  5 37 16  3 56 11 23 72  7  8 |  3 79 35 45 72 69 15 14 48 88 96 37 11 75 83 56 23  7 16 50 21 91 32 97 17'

# %% [markdown]
# ## Part 1
# - Card 1: 41 48 83 86 17 | 83 86  6 31 17  9 48 53
# - Card 2: 13 32 20 16 61 | 61 30 68 82 17 32 24 19
# - Card 3:  1 21 53 59 44 | 69 82 63 72 16 21 14  1
# - Card 4: 41 92 73 84 69 | 59 84 76 51 58  5 54 83
# - Card 5: 87 83 26 28 32 | 88 30 70 12 93 22 82 36
# - Card 6: 31 18 13 56 72 | 74 77 10 23 35 67 36 11
#
#
# find winning numbers
# first match is one and then every match after that is doubled
# Ex:
# Card 1: has 4 winning numbers so 1, 2, 4, 8
#
# - Card 2 has two winning numbers (32 and 61), so it is worth 2 points.
# - Card 3 has two winning numbers (1 and 21), so it is worth 2 points.
# - Card 4 has one winning number (84), so it is worth 1 point.
# - Card 5 has no winning numbers, so it is worth no points.
# - Card 6 has no winning numbers, so it is worth no points.

# %%
winning_dict = {}
scratch_nums_dict = {}

def get_winning_nums(row):
    card_num, winning_nums = row.split("|")[0].split(":")
    scratch_nums = row.split("|")[1]
    winning_dict[card_num] = winning_nums.split()
    scratch_nums_dict[card_num] = scratch_nums.split()
    return winning_dict,scratch_nums

for card in file:
    get_winning_nums(card)

# %%
test_dict = defaultdict(int)
matching_numbers = {}

for card, numbers in winning_dict.items():
    scratch_card_vals = scratch_nums_dict[card]
    matches = set(numbers) & set(scratch_card_vals)
    matching_numbers[card] = list(matches)

print(matching_numbers)
# Out:
# {'Card   1': ['72', '3', '37', '16', '7', '56', '11', '23'], 'Card   2': ['88', '1', '15', '45'], 'Card   3': ['37', '67', '99', '34', '43', '9', '41', '83', '44', '16'], 'Card   4': ['45', '7', '82', '99', '56', '9', '78', '17', '64', '57'], 'Card   5': ['88', '26', '63', '76'], 'Card   6': ['16', '38', '88', '49', '23', '22'], 'Card   7': ['81', '3', '37', '1', '20', '76', '31', '93', '6', '83'], 'Card   8': ['47', '11', '29', '66'], 'Card   9': ['11', '67', '28', '2', '74', '68', '8', '17', '47', '96'], 'Card  10': [], 'Card  11': [], 'Card  12': ['91', '59', '55'], 'Card  13': ['62', '58', '31', '92', '5', '84', '95'], 'Card  14': ['75', '12', '41', '6', '29'], 'Card  15': ['70', '28', '20', '88', '78', '16', '22'], 'Card  16': ['4', '42', '35', '68', '88', '78', '15', '17'], 'Card  17': ['13'], 'Card  18': ['99', '75', '87', '59', '25'], 'Card  19': [], 'Card  20': [], 'Card  21': ['48', '22'], 'Card  22': ['64', '55'], 'Card  23': ['27'], 'Card  24': [], 'Card  25': ['72', '2',
# ...

# %%
# get total score
total_score = 0
for card, matches in matching_numbers.items():
    if len(matches) == 0:
        total_score+=0
    else:
        score = 1
        for i in range(1, len(matches)):
            score *= 2
        total_score+= score

print(f"🚀{total_score}")
# Out:
# 🚀25571

# %% [markdown]
# # Part 2:
# - I could probably combine 1 and 2 into ones block but I'm tired lol

# %%
new_dict = defaultdict(int)

for idx, line in enumerate(file):
    new_dict[idx] += 1
    winning, scratch = line.split('|')
    card_id, card = winning.split(':')
    card_nums = [int(x) for x in card.split()]
    rest_nums = [int(x) for x in scratch.split()]
    value = len(set(card_nums) & set(rest_nums))
    if val > 0:
        continue
    for i in range(value):
        new_dict[idx+1+i] += new_dict[idx]
        
print(sum(new_dict.values()))
# Out:
# 8805731
