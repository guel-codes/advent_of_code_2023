# %% [markdown]
# # Advent of Code 2023

# %%
file = open('day_1_1.txt').read().strip().split('\n')
display(file[0])
# Out:
# 'Card   1:  5 37 16  3 56 11 23 72  7  8 |  3 79 35 45 72 69 15 14 48 88 96 37 11 75 83 56 23  7 16 50 21 91 32 97 17'

# %% [markdown]
# ## Part 1
# - Card 1: 41 48 83 86 17 | 83 86  6 31 17  9 48 53
# - Card 2: 13 32 20 16 61 | 61 30 68 82 17 32 24 19
# - Card 3:  1 21 53 59 44 | 69 82 63 72 16 21 14  1
# - Card 4: 41 92 73 84 69 | 59 84 76 51 58  5 54 83
# - Card 5: 87 83 26 28 32 | 88 30 70 12 93 22 82 36
# - Card 6: 31 18 13 56 72 | 74 77 10 23 35 67 36 11
#
#
# find winning numbers
# first match is one and then every match after that is doubled
# Ex:
# Card 1: has 4 winning numbers so 1, 2, 4, 8
#
# - Card 2 has two winning numbers (32 and 61), so it is worth 2 points.
# - Card 3 has two winning numbers (1 and 21), so it is worth 2 points.
# - Card 4 has one winning number (84), so it is worth 1 point.
# - Card 5 has no winning numbers, so it is worth no points.
# - Card 6 has no winning numbers, so it is worth no points.

# %%
winning_dict = {}
scratch_nums_dict = {}

def get_winning_nums(row):
    card_num, winning_nums = row.split("|")[0].split(":")
    scratch_nums = row.split("|")[1]
    winning_dict[card_num] = winning_nums.split()
    scratch_nums_dict[card_num] = scratch_nums.split()
    return winning_dict,scratch_nums

for card in file:
    get_winning_nums(card)

# %%
matching_numbers = {}

for card, numbers in winning_dict.items():
    scratch_card_vals = scratch_nums_dict[card]
    matches = set(numbers) & set(scratch_card_vals)
    matching_numbers[card] = list(matches)

print(matching_numbers)
# Out:
# {'Card   1': ['72', '37', '3', '16', '23', '11', '7', '56'], 'Card   2': ['45', '15', '1', '88'], 'Card   3': ['99', '67', '9', '44', '37', '16', '34', '43', '83', '41'], 'Card   4': ['99', '9', '57', '82', '64', '78', '7', '17', '45', '56'], 'Card   5': ['88', '76', '63', '26'], 'Card   6': ['16', '22', '23', '88', '38', '49'], 'Card   7': ['31', '37', '76', '3', '93', '20', '83', '1', '81', '6'], 'Card   8': ['11', '29', '47', '66'], 'Card   9': ['67', '96', '28', '8', '68', '74', '47', '11', '17', '2'], 'Card  10': [], 'Card  11': [], 'Card  12': ['91', '55', '59'], 'Card  13': ['84', '31', '95', '62', '92', '5', '58'], 'Card  14': ['75', '12', '29', '6', '41'], 'Card  15': ['28', '16', '70', '22', '88', '20', '78'], 'Card  16': ['42', '15', '88', '68', '35', '78', '17', '4'], 'Card  17': ['13'], 'Card  18': ['99', '25', '87', '75', '59'], 'Card  19': [], 'Card  20': [], 'Card  21': ['48', '22'], 'Card  22': ['55', '64'], 'Card  23': ['27'], 'Card  24': [], 'Card  25': ['9', '95', '72', '5', '88', '83', '90', '2'], 'Card  26': ['97', '96', '95', '27', '15', '63', '40'], 'Card  27': ['96', '44', '34', '92', '21', '88', '81', '66', '63', '2'], 'Card  28': ['31', '76', '57', '89', '87', '8', '50'], 'Card  29': ['52'], 'Card  30': ['91', '96', '10', '80', '70', '58', '20', '11', '85', '51'], 'Card  31': ['98', '89', '93', '55', '22', '29', '36', '94'], 'Card  32': ['71', '9', '65', '92', '87', '55', '12', '59', '85', '6'], 'Card  33': ['3', '62', '61', '8', '14', '12', '77', '90', '60', '94'], 'Card  34': ['44', '19', '50', '53', '88', '20', '68', '29', '4', '56'], 'Card  35': [], 'Card  36': ['71', '97', '9', '32', '76', '87', '77', '54', '24'], 'Card  37': ['99', '95', '88', '58', '38', '60'], 'Card  38': ['4'], 'Card  39': ['46', '80', '39', '75', '17'], 'Card  40': ['39', '28'], 'Card  41': ['97', '88', '75', '80'], 'Card  42': ['99', '97', '42', '10', '98', '15', '74'], 'Card  43': ['93', '87', '74', '56'], 'Card  44': ['78'], 'Card  45': ['84', '90', '65', '15'], 'Card  46': ['8', '54', '62'], 'Card  47': ['50'], 'Card  48': ['37'], 'Card  49': [], 'Card  50': ['65', '16', '57', '81', '54', '6'], 'Card  51': ['76', '92', '25', '39', '55', '82', '48', '83', '81', '56'], 'Card  52': ['99', '25', '93', '13', '64', '59', '47', '60', '81', '56'], 'Card  53': ['96', '92', '20', '12', '1', '59', '66', '49', '2', '56'], 'Card  54': [], 'Card  55': ['84', '91', '43', '37', '93', '70', '5', '64', '2', '69'], 'Card  56': ['53', '72', '17', '52'], 'Card  57': ['83'], 'Card  58': ['71', '97', '72', '95', '87', '77', '49', '24'], 'Card  59': ['90'], 'Card  60': ['97', '81'], 'Card  61': ['68'], 'Card  62': ['52', '74', '64'], 'Card  63': ['96', '16', '89', '57', '61'], 'Card  64': ['90'], 'Card  65': ['8'], 'Card  66': ['88'], 'Card  67': ['63', '12', '42'], 'Card  68': [], 'Card  69': ['82'], 'Card  70': ['53'], 'Card  71': [], 'Card  72': ['33', '57', '8', '58', '68', '38', '59', '36', '24'], 'Card  73': ['28', '51', '87', '64', '83', '35', '60', '17', '6', '56'], 'Card  74': ['97', '44', '42', '61', '82', '88', '1', '85', '40', '56'], 'Card  75': ['43', '37', '89', '93', '15', '8', '83', '90', '17', '50'], 'Card  76': [], 'Card  77': ['84', '27', '70', '22', '75', '48', '77', '36', '94', '6'], 'Card  78': [], 'Card  79': ['84', '42', '30', '70', '15', '75', '38', '17', '40', '51'], 'Card  80': ['32', '82'], 'Card  81': ['71', '15', '82', '20', '78'], 'Card  82': ['99', '95', '42', '14', '60', '94', '2', '40', '56'], 'Card  83': ['31', '56', '39', '23', '73', '59', '60', '63', '4', '24'], 'Card  84': ['63'], 'Card  85': ['99', '43', '22', '82', '35', '1', '60', '24'], 'Card  86': ['43', '67', '32', '80', '27', '57', '48', '11'], 'Card  87': ['44', '76', '25', '15', '13', '35', '81', '51'], 'Card  88': ['37', '56', '83', '11', '40', '66'], 'Card  89': [], 'Card  90': ['44', '74'], 'Card  91': ['33'], 'Card  92': ['29', '10'], 'Card  93': ['31', '1'], 'Card  94': ['12'], 'Card  95': [], 'Card  96': ['24', '98', '57', '93', '82', '20',  ...

# %%
# get total score
total_score = 0
for card, matches in matching_numbers.items():
    if len(matches) == 0:
        total_score+=0
    else:
        score = 1
        for i in range(1, len(matches)):
            score *= 2
        total_score+= score

print(f"🚀{total_score}")
# Out:
# 🚀25571
