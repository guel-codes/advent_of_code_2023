# %% [markdown]
# # Advent of Code 2023

# %%
file = open('day_1_1.txt').read().strip().split('\n')
display(file[0])
# Out:
# 'Card   1:  5 37 16  3 56 11 23 72  7  8 |  3 79 35 45 72 69 15 14 48 88 96 37 11 75 83 56 23  7 16 50 21 91 32 97 17'

# %% [markdown]
# ## Part 1
# - Card 1: 41 48 83 86 17 | 83 86  6 31 17  9 48 53
# - Card 2: 13 32 20 16 61 | 61 30 68 82 17 32 24 19
# - Card 3:  1 21 53 59 44 | 69 82 63 72 16 21 14  1
# - Card 4: 41 92 73 84 69 | 59 84 76 51 58  5 54 83
# - Card 5: 87 83 26 28 32 | 88 30 70 12 93 22 82 36
# - Card 6: 31 18 13 56 72 | 74 77 10 23 35 67 36 11
#
#
# find winning numbers
# first match is one and then every match after that is doubled
# Ex:
# Card 1: has 4 winning numbers so 1, 2, 4, 8
#
# - Card 2 has two winning numbers (32 and 61), so it is worth 2 points.
# - Card 3 has two winning numbers (1 and 21), so it is worth 2 points.
# - Card 4 has one winning number (84), so it is worth 1 point.
# - Card 5 has no winning numbers, so it is worth no points.
# - Card 6 has no winning numbers, so it is worth no points.

# %%
winning_dict = {}
scratch_nums_dict = {}

def get_winning_nums(row):
    card_num, winning_nums = row.split("|")[0].split(":")
    scratch_nums = row.split("|")[1]
    winning_dict[card_num] = winning_nums.split()
    scratch_nums_dict[card_num] = scratch_nums.split()
    return winning_dict,scratch_nums

for card in file:
    get_winning_nums(card)

matching_numbers = {}

for card, numbers in winning_dict.items():
    scratch_card_vals = scratch_nums_dict[card]
    matches = set(numbers) & set(scratch_card_vals)
    matching_numbers[card] = list(matches)

print(matching_numbers)

# get total score
total_score = 0
for card, matches in matching_numbers.items():
    if len(matches) == 0:
        total_score+=0
    else:
        score = 1
        for i in range(1, len(matches)):
            score *= 2
        total_score+= score

print(f"🚀{total_score}")
# Out:
# {'Card   1': ['3', '7', '56', '23', '37', '16', '11', '72'], 'Card   2': ['88', '1', '45', '15'], 'Card   3': ['67', '83', '34', '9', '99', '37', '43', '16', '41', '44'], 'Card   4': ['9', '57', '78', '99', '7', '56', '17', '82', '64', '45'], 'Card   5': ['76', '26', '88', '63'], 'Card   6': ['22', '88', '49', '23', '38', '16'], 'Card   7': ['83', '81', '20', '6', '1', '3', '31', '93', '37', '76'], 'Card   8': ['29', '11', '47', '66'], 'Card   9': ['67', '68', '2', '96', '74', '28', '17', '11', '47', '8'], 'Card  10': [], 'Card  11': [], 'Card  12': ['91', '59', '55'], 'Card  13': ['58', '62', '84', '5', '31', '95', '92'], 'Card  14': ['29', '75', '6', '12', '41'], 'Card  15': ['22', '88', '78', '20', '70', '28', '16'], 'Card  16': ['88', '78', '68', '17', '4', '42', '35', '15'], 'Card  17': ['13'], 'Card  18': ['25', '59', '75', '99', '87'], 'Card  19': [], 'Card  20': [], 'Card  21': ['22', '48'], 'Card  22': ['64', '55'], 'Card  23': ['27'], 'Card  24': [], 'Card  25': ['83', '88', '9', '2', '5', '95', '90', '72'], 'Card  26': ['27', '15', '96', '95', '97', '63', '40'], 'Card  27': ['21', '34', '88', '81', '2', '96', '66', '92', '63', '44'], 'Card  28': ['57', '50', '31', '89', '76', '87', '8'], 'Card  29': ['52'], 'Card  30': ['80', '58', '96', '20', '10', '70', '85', '11', '91', '51'], 'Card  31': ['36', '22', '98', '29', '89', '93', '55', '94'], 'Card  32': ['59', '9', '71', '6', '12', '85', '55', '92', '65', '87'], 'Card  33': ['14', '62', '3', '12', '8', '60', '61', '94', '77', '90'], 'Card  34': ['19', '88', '50', '29', '68', '20', '56', '53', '4', '44'], 'Card  35': [], 'Card  36': ['24', '9', '71', '32', '97', '54', '77', '76', '87'], 'Card  37': ['58', '88', '99', '95', '60', '38'], 'Card  38': ['4'], 'Card  39': ['80', '46', '39', '75', '17'], 'Card  40': ['28', '39'], 'Card  41': ['80', '75', '88', '97'], 'Card  42': ['98', '99', '10', '74', '97', '42', '15'], 'Card  43': ['56', '74', '87', '93'], 'Card  44': ['78'], 'Card  45': ['84', '15', '90', '65'], 'Card  46': ['54', '8', '62'], 'Card  47': ['50'], 'Card  48': ['37'], 'Card  49': [], 'Card  50': ['57', '81', '54', '6', '65', '16'], 'Card  51': ['83', '25', '48', '39', '81', '56', '55', '92', '82', '76'], 'Card  52': ['25', '59', '81', '13', '99', '56', '60', '93', '64', '47'], 'Card  53': ['59', '2', '49', '96', '1', '20', '56', '12', '66', '92'], 'Card  54': [], 'Card  55': ['84', '2', '5', '70', '43', '93', '37', '69', '64', '91'], 'Card  56': ['53', '52', '17', '72'], 'Card  57': ['83'], 'Card  58': ['24', '49', '71', '95', '97', '77', '87', '72'], 'Card  59': ['90'], 'Card  60': ['97', '81'], 'Card  61': ['68'], 'Card  62': ['64', '74', '52'], 'Card  63': ['57', '96', '89', '16', '61'], 'Card  64': ['90'], 'Card  65': ['8'], 'Card  66': ['88'], 'Card  67': ['12', '42', '63'], 'Card  68': [], 'Card  69': ['82'], 'Card  70': ['53'], 'Card  71': [], 'Card  72': ['36', '58', '24', '59', '57', '68', '33', '38', '8'], 'Card  73': ['83', '6', '56', '28', '17', '60', '35', '64', '51', '87'], 'Card  74': ['88', '1', '56', '97', '85', '44', '61', '82', '42', '40'], 'Card  75': ['83', '15', '50', '89', '17', '93', '43', '37', '90', '8'], 'Card  76': [], 'Card  77': ['36', '22', '27', '48', '84', '75', '6', '70', '94', '77'], 'Card  78': [], 'Card  79': ['84', '75', '70', '40', '17', '30', '38', '42', '51', '15'], 'Card  80': ['82', '32'], 'Card  81': ['78', '71', '20', '82', '15'], 'Card  82': ['14', '2', '99', '95', '56', '60', '94', '42', '40'], 'Card  83': ['24', '59', '39', '31', '56', '23', '73', '4', '60', '63'], 'Card  84': ['63'], 'Card  85': ['22', '24', '1', '99', '60', '43', '82', '35'], 'Card  86': ['67', '80', '27', '57', '48', '32', '43', '11'], 'Card  87': ['25', '81', '13', '44', '76', '51', '35', '15'], 'Card  88': ['83', '56', '66', '37', '11', '40'], 'Card  89': [], 'Card  90': ['74', '44'], 'Card  91': ['33'], 'Card  92': ['29', '10'], 'Card  93': ['31', '1'], 'Card  94': ['12'], 'Card  95': [], 'Card  96': ['24', '98', '57', '50', '1', '20', ' ...
# 🚀25571
